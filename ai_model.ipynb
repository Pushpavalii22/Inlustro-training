# %% [markdown]
# <a href="https://colab.research.google.com/github/Pushpavalii22/Inlustro-training/blob/main/ai_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from diffusers import StableDiffusionPipeline
import torch
pipe=StableDiffusionPipeline.from_pretrained("runwayml/stable-diffusion-v1-5")
pipe.to("cpu")
prompt="The flower is red in colour"
image=pipe(prompt).images[0]
image.show()
image.save("generated_image.png")
# Out:
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-f42dd9e76e8d> in <cell line: 0>()
#       4 pipe.to("cpu")
#       5 prompt="The flower is red in colour"
# ----> 6 image=pipe(prompt).images[0]
#       7 image.show()
#       8 image.save("generated_image.png")
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     114     def decorate_context(*args, **kwargs):
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
#     118     return decorate_context
#
# ...

# %%
from google.generativeai import GenerativeModel, configure
configure(api_key="AIzaSyD3erP9ziHIfB_1zZXe3LFbdzVVDgiqHOw")
model=GenerativeModel("gemini-1.5-pro")
r=model.generate_content("Who are you")
print(r.text)
r=model.generate_content("What is your name")
# Out:
# I am a large language model, trained by Google.  I am an AI chatbot, able to communicate in response to a wide range of prompts and questions, but my knowledge about the world is limited to the data I was trained on.
